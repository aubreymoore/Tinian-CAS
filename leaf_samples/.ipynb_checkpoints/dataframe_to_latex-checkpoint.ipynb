# %%
import pandas as pd

# %%
df = pd.read_csv('leaf_samples.csv')
df
# Out:
#     plot  tree  latitude  longitude        date  cas black scale predation  \
# 0      4    39       NaN        NaN  2022-02-26   no         yes        no
# 1     13   436       NaN        NaN  2022-02-26  yes          no        no
# 2     15   685       NaN        NaN  2022-02-26  yes          no        no
# 3     16   503       NaN        NaN  2022-02-26  yes          no        no
# 4     17   439       NaN        NaN  2022-02-26  yes          no        no
# 5     14   472       NaN        NaN  2022-02-26  yes          no        no
# 6     18   464       NaN        NaN  2022-02-26  yes          no        no
# 7     12   458       NaN        NaN  2022-02-26  yes          no        no
# 8      6   373       NaN        NaN  2022-02-26  yes          no        no
# 9      8   421       NaN        NaN  2022-02-26  yes          no        no
# 10    19   469       NaN        NaN  2022-02-26  yes          no        no
# ...

# %%
print(
    df.to_latex(
        index=False,na_rep='',
        caption='caption',
        label='leaf_samples_table'
    )
)
# Out:
# \begin{table}
# \centering
# \caption{caption}
# \label{leaf_samples_table}
# \begin{tabular}{rrrrllllll}
# \toprule
#  plot &  tree &  latitude &  longitude &       date & cas & black scale & predation & parasitism &       notes \\
# \midrule
#     4 &    39 &           &            & 2022-02-26 &  no &         yes &        no &         no &             \\
#    13 &   436 &           &            & 2022-02-26 & yes &          no &        no &         no &             \\
#    15 &   685 &           &            & 2022-02-26 & yes &          no &        no &         no &             \\
#    16 &   503 &           &            & 2022-02-26 & yes &          no &        no &         no &             \\
#    17 &   439 &           &            & 2022-02-26 & yes &          no &        no &         no &             \\
#    14 &   472 &           &            & 2022-02-26 & yes &          no &        no &         no &             \\
# ...
